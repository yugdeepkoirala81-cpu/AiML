# %%
import numpy as np

# %% [markdown]
# # random numbers

# %%
rand_arr=np.random.rand(4,4)
rand_arr
# Out:
# array([[0.80709299, 0.00424374, 0.34975951, 0.7622484 ],
#        [0.38049921, 0.18507664, 0.26603322, 0.27732574],
#        [0.16914069, 0.21238809, 0.76274821, 0.7951547 ],
#        [0.79824166, 0.21513343, 0.46979439, 0.0694021 ]])

# %%
ar1=np.random.randint(10,20, size=(3,4))
ar1
# Out:
# array([[13, 17, 13, 14],
#        [14, 16, 10, 11],
#        [19, 10, 11, 10]], dtype=int32)
